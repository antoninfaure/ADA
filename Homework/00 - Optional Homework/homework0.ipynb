# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('interactive_data.csv')

# %%
data
# Out:
#      Unnamed: 0         Intent         Gender            Age  \
# 0             1  None selected  None selected  None selected
# 1             2  None selected  None selected  None selected
# 2             3  None selected  None selected  None selected
# 3             4  None selected  None selected  None selected
# 4             5  None selected  None selected  None selected
# ..          ...            ...            ...            ...
# 535         536        Unknown           Male              5
# 536         537        Unknown           Male              5
# 537         538        Unknown           Male              5
# 538         539        Unknown           Male              5
# 539         540        Unknown           Male              5
#
#                        Race  Deaths  Population  Rate
# 0             None selected   33599   316299978  10.6
# 1                     White   22079   197369634  11.2
# 2                     Black    7765    38896382  20.0
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0        Deaths    Population    Rate
# count  540.000000    540.000000  5.400000e+02  468.00
# mean   270.500000    995.518519  2.342963e+07     inf
# std    156.028843   3322.544944  4.501642e+07     NaN
# min      1.000000      0.000000  0.000000e+00    0.00
# 25%    135.750000      1.000000  1.428743e+06    0.10
# 50%    270.500000     22.000000  6.856696e+06    0.45
# 75%    405.250000    191.750000  2.490155e+07    3.40
# max    540.000000  33599.000000  3.163000e+08     inf

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10))

data \
    .groupby('Intent')['Deaths'].sum() \
    .plot(kind='pie', title='Deaths by intent', ax=ax1, ylabel='', autopct='%1.1f%%')

data[data['Intent'] != 'None selected'] \
    .groupby('Intent')['Deaths'].sum() \
    .plot(kind='pie', title='(selected)', ax=ax2, ylabel='', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '(selected)'}>

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10))

data.loc[(data['Intent'] == 'Suicide')] \
    .groupby('Gender')['Deaths'].sum() \
        .plot(kind='pie', title='Suicide deaths by gender', ax=ax1, ylabel='', autopct='%1.1f%%')

data.loc[(data['Intent'] == 'Suicide') & (data['Gender'] != 'None selected')] \
    .groupby('Gender')['Deaths'].sum() \
        .plot(kind='pie', title='(selected)', ax=ax2, ylabel='', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '(selected)'}>

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10))


data.loc[(data['Intent'] == 'Homicide') & (data['Gender'] == 'Male') & (data['Age'] == '15 - 34')] \
    .groupby('Race')['Deaths'].sum() \
    .plot(kind='pie', title='Homicide deaths by race of male aged 15-34', ax=ax1, ylabel='', autopct='%1.1f%%')

data.loc[(data['Intent'] == 'Homicide') & (data['Gender'] == 'Male') & (data['Age'] == '15 - 34') & (data['Race'] != 'None selected')] \
    .groupby('Race')['Deaths'].sum() \
    .plot(kind='pie', title='(selected)', ax=ax2, ylabel='', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '(selected)'}>

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10))

data.loc[(data['Intent'] == 'Homicide')] \
    .groupby('Gender')['Deaths'].sum() \
    .plot(kind='pie', title='Homicide deaths by gender', ax=ax1, ylabel='', autopct='%1.1f%%')

data.loc[(data['Intent'] == 'Homicide') & (data['Gender'] != 'None selected')] \
    .groupby('Gender')['Deaths'].sum() \
    .plot(kind='pie', title='(selected)', ax=ax2, ylabel='', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '(selected)'}>
